# %% [markdown]
# <a href="https://colab.research.google.com/github/Florencia014/predicciones_de_ventas/blob/main/predicciones_de_ventas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
filename = '/content/sales_predictions_2023.csv'

# %%
df = pd.read_csv(filename)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
dt = df.duplicated()
dt[dt==True]
dt.any()
# Out:
# False

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head()
df.shape
# Out:
# (4650, 12)

# %%
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
for column in df.columns:
  print(column, df[column].value_counts())
# Out:
# Item_Identifier FDH26    5
# FDL51    5
# FDJ09    5
# FDB15    5
# FDC17    5
#         ..
# FDE40    1
# FDF50    1
# NCA42    1
# FDK32    1
# FDO03    1
# Name: Item_Identifier, Length: 1535, dtype: int64
# Item_Weight 12.150    58
# 17.600    55
# 13.650    49
# 11.800    49
# 16.000    45
#           ..
# 6.965      1
# 9.035      1
# 7.260      1
# 7.360      1
# 6.440      1
# Name: Item_Weight, Length: 409, dtype: int64
# Item_Fat_Content Low Fat    2774
# Regular    1575
# LF          177
# reg          71
# low fat      53
# Name: Item_Fat_Content, dtype: int64
# Item_Visibility 0.000000    292
# 0.076975      3
# 0.121250      2
# 0.046825      2
# 0.026950      2
#            ...
# 0.039248      1
# 0.040946      1
# 0.031332      1
# 0.026841      1
# 0.044878      1
# Name: Item_Visibility, Length: 4280, dtype: int64
# Item_Type Fruits and Vegetables    670
# Snack Foods              656
# Household                498
# Frozen Foods             477
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  4650.000000      4650.000000  4650.000000                4650.000000
# mean     12.898675         0.060700   141.716328                1999.190538
# std       4.670973         0.044607    62.420534                   7.388800
# min       4.555000         0.000000    31.490000                1987.000000
# 25%       8.770000         0.025968    94.409400                1997.000000
# 50%      12.650000         0.049655   142.979900                1999.000000
# 75%      17.000000         0.088736   186.614150                2004.000000
# max      21.350000         0.188323   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        4650.000000
# mean         2272.037489
# std          1497.964740
# min            69.243200
# 25%          1125.202000
# 50%          1939.808300
# 75%          3111.616300
# max         10256.649000

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn import set_config
set_config(display='diagram')

# %%
df_ml=pd.read_csv(filename)
df_ml.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
X=df_ml.drop(columns=['Item_Outlet_Sales','Item_Identifier','Outlet_Establishment_Year'])
#Se eliminan columnas no útiles para modelar.
y=df_ml['Item_Outlet_Sales']

# %%
outlet_sizes = {'Small': 0, 'Medium': 1, 'High': 2}
item_fat = {'Low Fat':0, 'Regular':1}

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)
X_train['Outlet_Size'] = X_train['Outlet_Size'].replace(outlet_sizes)
X_test['Outlet_Size'] = X_test['Outlet_Size'].replace(outlet_sizes)
X_train['Item_Fat_Content'] = X_train['Item_Fat_Content'].replace(item_fat)
X_test['Item_Fat_Content'] = X_test['Item_Fat_Content'].replace(item_fat)

# %%
cat_selector = make_column_selector(dtype_include='object')
num_selector = make_column_selector(dtype_include='number')

mean_imputer = SimpleImputer(strategy='mean')
freq_imputer = SimpleImputer(strategy='most_frequent')

# %%
ohe = OneHotEncoder(handle_unknown= 'ignore', sparse=False)
scaler = StandardScaler()

# %%
num_pipeline = make_pipeline(mean_imputer, scaler)
cat_pipeline = make_pipeline(freq_imputer, ohe)

# %%
num_tupla = (num_pipeline, num_selector)
cat_tupla = (cat_pipeline, ['Item_Type', 'Outlet_Identifier', 'Outlet_Location_Type', 'Outlet_Type'])
cat2_tupla = (freq_imputer, ['Item_Fat_Content', 'Outlet_Size'])

# %%
preprocessor = make_column_transformer(num_tupla, cat_tupla, cat2_tupla)

# %%
preprocessor.fit(X_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7e577acce260>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
# ...

# %%
X_train_processed = preprocessor.transform(X_train)
X_test_processed = preprocessor.transform(X_test)
